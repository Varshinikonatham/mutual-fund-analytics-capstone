# %% [markdown]
# # Performance Analytics - Mutual Fund Capstone
# ### Milestone: Fund Performance Analytics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

scorecard = pd.read_csv('fund_scorecard.csv')
alpha_beta = pd.read_csv('alpha_beta.csv')
scorecard.head(10)

# %% [markdown]
# ## 1. Top 5 Funds Comparison Table (by Composite Score)

# %%
scorecard.head(5)

# %% [markdown]
# ## 2. Risk vs Return Profile (Alpha & Beta Summary)

# %%
alpha_beta.describe()

# %% [markdown]
# ## 3. Benchmark Comparison Visualization

# %%
from IPython.display import Image
Image('benchmark_comparison_chart.png')
