# %% [markdown]
# # Milestone: Exploratory Data Analysis (EDA)
# **Capstone Project I - Mutual Fund Analytics**
# This notebook covers data discovery, time-series movements, investor profiles, and market correlations across the mutual fund universe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display

# %% [markdown]
# ### 1. NAV Trend Analysis
# **Key Insight:** The 40 analyzed schemes exhibited aggressive growth during the 2023 bull rally, followed by moderate volatility in mid-2024 before continuing on an upward trajectory into 2026. *(Supporting visual: `eda_1_nav_trend.png`)*

# %%
display(Image('../reports/eda_1_nav_trend.png'))

# %% [markdown]
# ### 2. AMC AUM Dominance
# **Key Insight:** SBI Mutual Fund maintained distinct market leadership across all four years, crossing ₹12.5 Lakh Crore in managed assets with strong institutional inflows. *(Supporting visual: `eda_2_aum_growth.png`)*

# %%
display(Image('../reports/eda_2_aum_growth.png'))

# %% [markdown]
# ### 3. Monthly SIP Inflow Trajectory
# **Key Insight:** Systematic Investment Plans experienced exponential adoption, ascending consistently to an all-time peak of ₹31,002 Crore by December 2025. *(Supporting visual: `eda_3_sip_inflows.png`)*

# %%
display(Image('../reports/eda_3_sip_inflows.png'))

# %% [markdown]
# ### 4. Category-Wise Inflow Intensity
# **Key Insight:** Sectoral and thematic equity schemes experienced intense cyclical inflows during mid-year market rallies, while flexi-cap and large-cap categories provided consistent baselines. *(Supporting visual: `eda_4_category_heatmap.png`)*

# %%
display(Image('../reports/eda_4_category_heatmap.png'))

# %% [markdown]
# ### 5. Investor Demographics - Age Slices
# **Key Insight:** Working adults aged 31–45 form the core demographic representing over 40% of the active mutual fund investor base. *(Supporting visual: `eda_5_age_pie.png`)*

# %%
display(Image('../reports/eda_5_age_pie.png'))

# %% [markdown]
# ### 6. SIP Ticket Size vs Investor Age
# **Key Insight:** Ticket sizes scale positively with age brackets; investors in the 46–60 segment maintain the highest median monthly commitments due to accumulated discretionary income. *(Supporting visual: `eda_6_age_sip_box.png`)*

# %%
display(Image('../reports/eda_6_age_sip_box.png'))

# %% [markdown]
# ### 7. Demographic Gender Representation
# **Key Insight:** While male investors maintain the majority share, female participation shows an upward trajectory exceeding 26% across retail folios. *(Supporting visual: `eda_7_gender_split.png`)*

# %%
display(Image('../reports/eda_7_gender_split.png'))

# %% [markdown]
# ### 8. Geographic SIP Distribution
# **Key Insight:** Maharashtra, Gujarat, and Karnataka dominate total aggregate SIP contributions, driven by higher financial literacy and corporate concentration. *(Supporting visual: `eda_8_state_distribution.png`)*

# %%
display(Image('../reports/eda_8_state_distribution.png'))

# %% [markdown]
# ### 9. Geographic Penetration (T30 vs B30)
# **Key Insight:** Beyond Top 30 (B30) cities account for nearly a third of all monthly inflows, underscoring strong mutual fund penetration into Tier-2 and Tier-3 geographies. *(Supporting visual: `eda_9_t30_b30_tier.png`)*

# %%
display(Image('../reports/eda_9_t30_b30_tier.png'))

# %% [markdown]
# ### 10. Industry Folio Growth & Correlation
# **Key Insight:** Total mutual fund folios nearly doubled from 13.26 Crore in Jan 2022 to 26.12 Crore in Dec 2025, driven by seamless digital onboarding channels. *(Supporting visual: `eda_10_folio_growth.png`)*

# %%
display(Image('../reports/eda_10_folio_growth.png'))
